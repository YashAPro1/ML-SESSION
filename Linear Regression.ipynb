# %%
#Importing all the libraries that we need
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("linearregeression.csv")

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# Preprocessing Data

# %%
data.shape
# Out:
# (14620, 23)

# %%
data.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
import math
print(math.ceil(2.001))
# Out:
# 3

# %%
data['number of bathrooms'] = data['number of bathrooms'].apply(lambda x: math.ceil(x))
data['number of floors'] = data['number of floors'].apply(lambda x: math.ceil(x))

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                    3         3650
# 1  6762810635  42491                   4                    3         2920
# 2  6762810998  42491                   5                    3         2910
# 3  6762812605  42491                   4                    3         3310
# 4  6762812919  42491                   3                    2         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050                 2                   0                4
# 1      4000                 2                   0                0
# 2      9480                 2                   0                0
# 3     42998                 2                   0                0
# 4      4500                 2                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
# Lets check the dependencies

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.457387
# std    6.237575e+03     67.347991            0.938719             0.922707
# min    6.762810e+09  42491.000000            1.000000             1.000000
# 25%    6.762815e+09  42546.000000            3.000000             2.000000
# 50%    6.762821e+09  42600.000000            3.000000             3.000000
# 75%    6.762826e+09  42662.000000            4.000000             3.000000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.551368            0.007661
# std      928.275721  3.791962e+04          0.567758            0.087193
# ...

# %%
df1 = data.drop(['number of floors','number of views',"condition of the house","Built Year","Renovation Year","Number of schools nearby","living_area_renov","lot_area_renov","id","Date","waterfront present","grade of the house"],axis='columns')

# %%
df1.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport    Price
# ...

# %%
df1.shape
# Out:
# (14620, 11)

# %%
df1.describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14620.000000         14620.000000  14620.000000  1.462000e+04
# mean             3.379343             2.457387   2098.262996  1.509328e+04
# std              0.938719             0.922707    928.275721  3.791962e+04
# min              1.000000             1.000000    370.000000  5.200000e+02
# 25%              3.000000             2.000000   1440.000000  5.010750e+03
# 50%              3.000000             3.000000   1930.000000  7.620000e+03
# 75%              4.000000             3.000000   2570.000000  1.080000e+04
# max             33.000000             8.000000  13540.000000  1.074218e+06
#
#        Area of the house(excluding basement)  Area of the basement  \
# count                           14620.000000          14620.000000
# mean                             1801.783926            296.479070
# std                               833.809963            448.551409
# ...

# %%
df2 = df1[~(df1['living area']/df1["number of bedrooms"]<300)]

# %%
df2.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport    Price
# ...

# %%
df2.shape
# Out:
# (14485, 11)

# %%
df2[df2["number of bathrooms"]>6]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 76                      7                    8        13540    307752
# 418                     5                    7         7270    130017
# 2425                    5                    7         8670     64033
# 2794                    5                    7         9640     13068
# 4061                    5                    7         8020     21738
# 6730                    9                    8         4050      6504
# 9171                    6                    8         9890     31374
# 10177                   7                    7         7480     41664
# 10503                   6                    8        12050     27600
#
#        Area of the house(excluding basement)  Area of the basement  \
# 76                                      9410                  4130
# 418                                     6420                   850
# ...

# %%
def remove_outliers(df):
    for index, x in df.iterrows():
        if x["number of bathrooms"]>x["number of bedrooms"]+1:
            df.drop(index,inplace=True)
    return df

# %%
----------------------------------------------------------
^        ^               ^             ^                 ^
IQR =    -------------------------------*1.5
# Out:
#   File "C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_22004\1527000181.py", line 1
#     ----------------------------------------------------------
#                                                               ^
# SyntaxError: invalid syntax

# %%
df3 = remove_outliers(df2)
# Out:
# C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_22004\2940422423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index,inplace=True)
# C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_22004\2940422423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index,inplace=True)
# C:\Users\Yashkumar Dubey\AppData\Local\Temp\ipykernel_22004\2940422423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df3.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport    Price
# ...

# %%
df3.shape
# Out:
# (14452, 11)

# %%
# Fetaures for testing and training
X= df3.drop("Price",axis = 1)

# %%
X.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                    3         3650      9050
# 1                   4                    3         2920      4000
# 2                   5                    3         2910      9480
# 3                   4                    3         3310     42998
# 4                   3                    2         2710      4500
#
#    Area of the house(excluding basement)  Area of the basement  Postal Code  \
# 0                                   3370                   280       122003
# 1                                   1910                  1010       122004
# 2                                   2910                     0       122004
# 3                                   3310                     0       122005
# 4                                   1880                   830       122006
#
#    Lattitude  Longitude  Distance from the airport
# 0    52.8645   -114.557                         58
# ...

# %%
#Traget Feature or dependent variable 
y = df3.Price

# %%
y
# Out:
# 0        2380000
# 1        1400000
# 2        1200000
# 3         838000
# 4         805000
#           ...
# 14614     240000
# 14615     221700
# 14616     219200
# 14617     209000
# 14619     146000
# Name: Price, Length: 14452, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 1.80661818,  0.59317594,  1.70416191, ...,  0.51991991,
#         -1.08630258, -0.77741948],
#        [ 0.69549187,  0.59317594,  0.90058788, ...,  0.68923808,
#         -0.47059874, -1.56106699],
#        [ 1.80661818,  0.59317594,  0.88958001, ...,  0.6703442 ,
#         -0.45644463, -1.3371677 ],
#        ...,
#        [-0.41563443, -0.50813171, -0.4643872 , ..., -2.07435417,
#          0.07433455, -0.66546983],
#        [-1.52676073, -1.60943935, -1.13586687, ..., -0.46546823,
#         -0.7324498 , -0.10572161],
#        [-0.41563443, -1.60943935, -1.32300055, ..., -1.88323538,
#         -1.05091731, -1.11326841]])

# %%
y
# Out:
# 0        2380000
# 1        1400000
# 2        1200000
# 3         838000
# 4         805000
#           ...
# 14614     240000
# 14615     221700
# 14616     219200
# 14617     209000
# 14619     146000
# Name: Price, Length: 14452, dtype: int64

# %%
# for testing and training
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.2,random_state=10)

# %%
X_train.shape
# Out:
# (11561, 10)

# %%
X_test.shape
# Out:
# (2891, 10)

# %%
11561+2891
# Out:
# 14452

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.5785948789232089
